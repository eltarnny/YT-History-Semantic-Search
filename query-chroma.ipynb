# %% [markdown]
# This is the code used in yt-history-api.py to get the results from ChromaDB

# %%
import ipywidgets
from tqdm.autonotebook import tqdm, trange
from sentence_transformers import SentenceTransformer
import pandas as pd

import chromadb

# %% [markdown]
# ### Select relevant documents from ChromaDB

# %%
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2', device='cuda')

# %%
number_of_results = 15

# %%
chroma_client = chromadb.PersistentClient(path="chroma")
collection = chroma_client.get_or_create_collection(name='yt-history')

# %%
query = "LLM with RAG"
qembeddings = [model.encode(query).astype('float').tolist()]

# %%
results = collection.query(
    query_embeddings=qembeddings, 
    n_results=number_of_results*10 # 10x more results in order to re-rank them
)

# %%
res_dicts = results['metadatas'][0]
df = pd.DataFrame(res_dicts).drop_duplicates(subset='video_id')
df.head(number_of_results)
# We can see that we have some relevant results, and some totally irrelevant ones
# Out:
#                datetime paragraph_number  \
# 0   2024-05-11 14:35:54              020
# 1   2024-05-02 19:04:59              000
# 2   2024-05-09 05:21:22              000
# 3   2024-05-05 21:46:49              000
# 5   2024-04-30 20:00:34              013
# 6   2024-05-17 06:36:50              000
# 12  2024-04-17 04:16:22              023
# 14  2024-05-12 19:25:58              003
# 15  2024-05-10 21:55:42              000
# 17  2024-05-01 15:30:43              000
# 18  2024-04-23 17:00:43              003
# 23  2024-05-11 12:40:30              000
# 25  2024-05-08 05:36:42              011
# 26  2024-05-29 16:52:07              000
# 28  2024-06-01 14:52:01              001
#
#                                                 title  \
# 0   Vector Search RAG Tutorial – Combine Your Data...
# 1        Reliable, fully local RAG agents with LLaMA3
# 2   Learn RAG From Scratch – Python AI Tutorial fr...
# 3      GraphRAG: LLM-Derived Knowledge Graphs for RAG
# 5   Python RAG Tutorial (with Local LLMs): AI For ...
# 6   How to Improve LLMs with RAG (Overview + Pytho...
# 12  The ULTIMATE Toxic Deck! | Finally Affliction ...
# 14  Function Calling with Local Models & LangChain...
# 15  Convert Any Webpage Into LLM Dataset - Local a...
# 17  Unleash the power of Local LLM's with Ollama x...
# 18   Use GPT-4, Claude 3 and Llama 3 in the Same Chat
# 23  New Summarization via In Context Learning with...
# 25  AN HONEST REVIEW of BLINK [Marvel Snap First I...
# 26  "okay, but I want Llama 3 for my specific use ...
# 28               LLaMA2 for Multilingual Fine Tuning?
#
#                                        titleUrl     video_id
# 0   https://www.youtube.com/watch?v=JEBDfGqrAUA  JEBDfGqrAUA
# 1   https://www.youtube.com/watch?v=-ROS6gfYIts  -ROS6gfYIts
# 2   https://www.youtube.com/watch?v=sVcwVQRHIc8  sVcwVQRHIc8
# 3   https://www.youtube.com/watch?v=r09tJfON6kE  r09tJfON6kE
# 5   https://www.youtube.com/watch?v=2TJxpyO3ei4  2TJxpyO3ei4
# 6   https://www.youtube.com/watch?v=Ylz779Op9Pw  Ylz779Op9Pw
# 12  https://www.youtube.com/watch?v=REMzzA4vamc  REMzzA4vamc
# 14  https://www.youtube.com/watch?v=Ss_GdU0KqE0  Ss_GdU0KqE0
# 15  https://www.youtube.com/watch?v=gn42k6OuJSc  gn42k6OuJSc
# 17  https://www.youtube.com/watch?v=IJYC6zf86lU  IJYC6zf86lU
# 18  https://www.youtube.com/watch?v=9vqaM7CHrsA  9vqaM7CHrsA
# 23  https://www.youtube.com/watch?v=6Yd6NdJrn4s  6Yd6NdJrn4s
# 25  https://www.youtube.com/watch?v=S7URHAxafPw  S7URHAxafPw
# 26  https://www.youtube.com/watch?v=pK8u4QfdLx0  pK8u4QfdLx0
# 28  https://www.youtube.com/watch?v=ThKWQcyQXF8  ThKWQcyQXF8

# %% [markdown]
# ### Re-Ranking

# %% [markdown]
# pip install -U FlagEmbedding

# %% [markdown]
# We will use the re-ranking technique in order to sort our results from the most relevant to theleast relevant.
# We will use code from here:
# https://huggingface.co/BAAI/bge-reranker-v2-m3

# %%
from FlagEmbedding import FlagReranker

# %%
reranker = FlagReranker('BAAI/bge-reranker-v2-m3', use_fp16=True, device='cuda')

# %%
pairs = [[query, doc] for doc in results['documents'][0]]

# %%
scores = reranker.compute_score(pairs, normalize=False)
# Out:
# Compute Scores: 100%|██████████| 1/1 [00:01<00:00,  1.24s/it]

# %%
# Sort results by relevance score

sorted_results = sorted(
    zip(
        results['ids'][0], 
        scores
        ), 
        key=lambda x: x[1], reverse=True
    )

# %%
sorted_ids = [row[0] for row in sorted_results]

# %%
res_ids = results['ids'][0] # chromadb results ids
doc_list = results['documents'][0] # chromadb results documents
res_meta_dicts = results['metadatas'][0] # chromadb results metadatas
df_meta = pd.DataFrame(res_meta_dicts) # create dataframe from metadatas
df_meta.drop('datetime', axis=1, inplace=True) # drop datetime
df_meta.insert(len(df_meta.columns), 'paragraph', doc_list)
df_meta.insert(0, 'id', res_ids) # add ids as first column in the dataframe
df_meta.set_index('id', inplace=True) # create index from ids
df_meta = df_meta.reindex(sorted_ids) # reindex dataframe with the sorted ids

# %%
df_meta = df_meta.drop_duplicates(subset='video_id') # drop duplicate videos
df_meta.reset_index(drop=True, inplace=True)
df_meta = df_meta.head(number_of_results) # keep only the first 15 videos

# %%
df_meta
# Out:
#    paragraph_number                                              title  \
# 0               001  Python RAG Tutorial (with Local LLMs): AI For ...
# 1               000     GraphRAG: LLM-Derived Knowledge Graphs for RAG
# 2               007  Unleash the power of Local LLM's with Ollama x...
# 3               000  Learn RAG From Scratch – Python AI Tutorial fr...
# 4               014                      Run your own AI (but private)
# 5               000  How to Improve LLMs with RAG (Overview + Pytho...
# 6               020  Vector Search RAG Tutorial – Combine Your Data...
# 7               000                Advance RAG with Azure & LlamaIndex
# 8               006          LangGraph 101: it's better than LangChain
# 9               004       Reliable, fully local RAG agents with LLaMA3
# 10              002  Ollama UI Tutorial - Incredible Local LLM UI W...
# 11              000               Google's RAG Experiment - NotebookLM
# 12              046  The End of Finetuning - with Jeremy Howard of ...
# 13              035          [1hr Talk] Intro to Large Language Models
# 14              003  Skimming This Week's New AI Papers - May 18, 2024
#
#                                        titleUrl     video_id  \
# 0   https://www.youtube.com/watch?v=2TJxpyO3ei4  2TJxpyO3ei4
# 1   https://www.youtube.com/watch?v=r09tJfON6kE  r09tJfON6kE
# 2   https://www.youtube.com/watch?v=IJYC6zf86lU  IJYC6zf86lU
# 3   https://www.youtube.com/watch?v=sVcwVQRHIc8  sVcwVQRHIc8
# 4   https://www.youtube.com/watch?v=WxYC9-hBM_g  WxYC9-hBM_g
# 5   https://www.youtube.com/watch?v=Ylz779Op9Pw  Ylz779Op9Pw
# 6   https://www.youtube.com/watch?v=JEBDfGqrAUA  JEBDfGqrAUA
# 7   https://www.youtube.com/watch?v=8Rbq6zHarZM  8Rbq6zHarZM
# 8   https://www.youtube.com/watch?v=qaWOwbFw3cs  qaWOwbFw3cs
# 9   https://www.youtube.com/watch?v=-ROS6gfYIts  -ROS6gfYIts
# 10  https://www.youtube.com/watch?v=w4ERVqyMNcI  w4ERVqyMNcI
# 11  https://www.youtube.com/watch?v=nK61ZpAS13s  nK61ZpAS13s
# 12  https://www.youtube.com/watch?v=5Sze3kHAZqE  5Sze3kHAZqE
# 13  https://www.youtube.com/watch?v=zjkBMFhNj_g  zjkBMFhNj_g
# 14  https://www.youtube.com/watch?v=pU44XI5uAGA  pU44XI5uAGA
#
#                                             paragraph
# 0   get up to speed with all of the basic concepts...
# 1   GraphRAG: LLM-Derived Knowledge Graphs for RAG...
# 2   thing which is ask llama 2 running on oama wha...
# 3   Learn RAG From Scratch – Python AI Tutorial fr...
# 4   it's accurate to make sure you got your stuff ...
# 5   How to Improve LLMs with RAG (Overview + Pytho...
# 6   address these issues. RAG uses vector search t...
# 7   Advance RAG with Azure & LlamaIndex finally we...
# 8   Library can actually be use for but this is a ...
# 9   constrained so it only ever traverses this pat...
# 10  featured and I I really appreciate that you ca...
# 11  Google's RAG Experiment - NotebookLM Okay. So ...
# 12  here's one way here's a different way differen...
# 13  I see a lot of equivalence between this new ll...
# 14  you would be able to um uh ignore the whole ll...

# %%
df_meta[['title', 'titleUrl', 'paragraph']].to_dict('records')
